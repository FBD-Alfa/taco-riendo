# %%
import pandas as pd
from random import seed
from random import randint
import random

personas = pd.read_csv ('Data/persona.csv')
personas.head()
# Out:
#     idPersona  esEmpleado  esCliente  esProveedor    idSucursal  nombre  \
# 0  1332119756        True       True        False  2.222748e+09  D'arcy
# 1  6063150911        True       True         True  9.218200e+09    Bent
# 2  4448788363        True       True         True  5.795416e+09  Norean
# 3  4685253514        True      False         True  6.210563e+09  Cortie
# 4  8170158101       False      False        False           NaN     Gav
#
#   apellidoP  apellidoM                     correo    telefono  ... antiguedad  \
# 0    Galero    Berthon        dberthon0@bbc.co.uk   795596920  ...       32.0
# 1     Heitz   Holtaway  bholtaway1@friendfeed.com  1054146623  ...       32.0
# 2   Hallatt    Gosland         ngosland2@ning.com  5100906475  ...       28.0
# 3   Penning  McManamen    cmcmanamen3@twitpic.com   593339463  ...       28.0
# 4  Aspinall       Woan       gwoan4@bloglines.com  2624492610  ...        NaN
#
# ...

# %%
consulta = pd.read_csv ('consemergencialeve.csv')
consulta.head()
# Out:
#    idConsulta         curpCliente nomMascota     curpVeterinario  idEstetica  \
# 0      490706  PEUO675539RJSITX31     Cooper  ZHVD345900BETGNH58           6
# 1      387917  NLVK694672MXQHXH44      Ferdy  BJWJ984464RHDEVK06           3
# 2      218274  DHUU340112UJDIZJ06     Georgy  NCBG570788GCRGVH93          18
# 3      243243  XORR257764OPJLYG12    Alaster  ZHVD345900BETGNH58          20
# 4      139222  HHGR445719LPFBZR39    Diahann  EEDD899567DLRAKD15          24
#
#    precioEmergencia        procedimiento
# 0               654     Lavado de herida
# 1               887  Curacion de heridas
# 2               911  Curacion de heridas
# 3               988     Lavado de herida
# 4               611     Lavado de herida

# %%
sintoma = pd.read_csv ('sintomaleve.csv')
sintoma.head()
# Out:
#    idConsulta              sintoma
# 0      910082      sudor abundante
# 1      448223         pulso rapido
# 2      395061  respiración cortada
# 3      933679              comezon
# 4      159972  respiración cortada

# %%
lista = ["temperatura", "vomito", "comezon", "diarrea", "espasmo", "cojear", "somnolencia", "hiperactividad", "sudor abundante", "respiración cortada", "pulso rapido", "nauseas"]
idconsultas = [consulta['idConsulta'][i] for i in range(200)]
random.shuffle(idconsultas)
for i in range(200):
    seed(i)
    sintoma['idConsulta'][i] = idconsultas[i]
    sintoma['sintoma'][i] = lista[randint(0,11)]
    
sintoma.head()
# Out:
# /tmp/ipykernel_77310/2067487266.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sintoma['idConsulta'][i] = idconsultas[i]
# /tmp/ipykernel_77310/2067487266.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sintoma['sintoma'][i] = lista[randint(0,11)]
#    idConsulta      sintoma
# 0      770028  somnolencia
# 1      170683      comezon
# 2      129859  temperatura
# 3      655186      diarrea
# 4      684318      diarrea

# %%
sintoma.to_csv('sintomaleve.csv', index=False)
